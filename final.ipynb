# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from process import *
from detectline import *

# %%
im = cv2.imread("./test1.jpg")
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
plotImage(im)

# %%
im_test= autoBrightnessContrast(im)
gray_test = cv2.cvtColor(im_test, cv2.COLOR_BGR2GRAY)
image, original_img, res, lines = getFrame(im)
plotImage(image)
plotImage(original_img)
plotImage(res)
# Out:
# 23
